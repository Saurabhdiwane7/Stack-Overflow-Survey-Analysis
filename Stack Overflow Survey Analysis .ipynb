# %% [markdown]
# Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv(r'C:\Users\saura\Downloads\developer_survey_2019\survey_results_public.csv')
data1
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                          Web development or web design  ...
# 3      Computer science, computer engineering, or sof...  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
data1.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# 0            NaN  Taught yourself a new language, framework, or ...     NaN
# 1            NaN  Taken an online course in programming or softw...     NaN
#
#                                              DevType YearsCode  Age1stCode  \
# 0                                                NaN         4        10.0
# 1  Developer, desktop or enterprise applications;...       NaN        17.0
#
#   YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant  \
# 0          NaN       NaN    NaN      NaN      NaN     NaN
# 1          NaN       NaN    NaN      NaN      NaN     NaN
#
#                            JobSeek          LastHireDate LastInt FizzBuzz  \
# 0                              NaN                   NaN     NaN      NaN
# 1  I am actively looking for a job  I've never had a job     NaN      NaN
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
#
#   CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan  \
# 0          NaN        NaN      NaN            NaN          NaN      NaN
# 1          NaN        NaN      NaN            NaN          NaN      NaN
#
#   WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests  \
# 0           NaN        NaN     NaN    NaN     NaN         NaN       NaN
# 1           NaN        NaN     NaN    NaN     NaN         NaN       NaN
#
#   PurchaseHow PurchaseWhat               LanguageWorkedWith  \
# 0         NaN          NaN  HTML/CSS;Java;JavaScript;Python
# 1         NaN          NaN              C++;HTML/CSS;Python
#
#                             LanguageDesireNextYear DatabaseWorkedWith  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite
# 1                      C++;HTML/CSS;JavaScript;SQL                NaN
#
#   DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith  \
# 0       Django;Flask           Flask;jQuery            Node.js
# 1             Django                 Django                NaN
#
#   MiscTechDesireNextYear                  DevEnviron    OpSys  \
# 0                Node.js  IntelliJ;Notepad++;PyCharm  Windows
# 1                    NaN                Atom;PyCharm  Windows
#
#                 Containers BlockchainOrg  \
# 0  I do not use containers           NaN
# 1  I do not use containers           NaN
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
#
#                                    ITperson OffOn SocialMedia Extraversion  \
# 0  Fortunately, someone else has that title   Yes     Twitter       Online
# 1                                       Yes   Yes   Instagram       Online
#
#   ScreenName SOVisit1st                      SOVisitFreq  \
# 0   Username       2017  A few times per month or weekly
# 1   Username       2017            Daily or almost daily
#
#                                            SOVisitTo        SOFindAnswer  \
# 0  Find answers to specific questions;Learn how t...  3-5 times per week
# 1  Find answers to specific questions;Learn how t...  3-5 times per week
#
#                       SOTimeSaved  SOHowMuchTime SOAccount  \
# 0  Stack Overflow was much faster  31-60 minutes        No
# 1  Stack Overflow was much faster  11-30 minutes       Yes
#
#                         SOPartFreq  \
# 0                              NaN
# 1  A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
#
#                               EntTeams         SOComm  \
# 0  No, and I don't know what those are        Neutral
# 1  No, and I don't know what those are  Yes, somewhat
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
# 1  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase  Younger than 5 years
# 0  Neither easy nor difficult                   NaN
# 1  Neither easy nor difficult                   NaN

# %%
data2 = pd.read_csv(r'C:\Users\saura\Downloads\developer_survey_2019\survey_results_schema.csv')
data2
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
data1.shape
# Out:
# (88883, 85)

# %%
data2.shape
# Out:
# (85, 2)

# %%
data1.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
data1.isna().sum()
# Out:
# Respondent          0
# MainBranch        552
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 85, dtype: int64

# %%
data2.isna().sum()
# Out:
# Column          0
# QuestionText    0
# dtype: int64

# %%
pd.set_option('display.max.columns',None)

# %%
data1.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                                NaN
# 1                                                NaN
# 2                      Web development or web design
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                             EduOther  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taken an online course in programming or softw...
# 2  Taught yourself a new language, framework, or ...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                     OrgSize  \
# 0                       NaN
# 1                       NaN
# 2      100 to 499 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
# 2  Designer;Developer, back-end;Developer, front-...         3         22
# 3                              Developer, full-stack         3         16
# 4  Academic researcher;Developer, desktop or ente...        16         14
#
#        YearsCodePro           CareerSat                 JobSat  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2                 1  Slightly satisfied     Slightly satisfied
# 3  Less than 1 year      Very satisfied     Slightly satisfied
# 4                 9   Very dissatisfied  Slightly dissatisfied
#
#                MgrIdiot  MgrMoney   MgrWant  \
# 0                   NaN       NaN       NaN
# 1                   NaN       NaN       NaN
# 2  Not at all confident  Not sure  Not sure
# 3        Very confident        No  Not sure
# 4    Somewhat confident       Yes        No
#
#                                              JobSeek          LastHireDate  \
# 0                                                NaN                   NaN
# 1                    I am actively looking for a job  I've never had a job
# 2  I’m not actively looking, but I am open to new...         1-2 years ago
# 3       I am not interested in new job opportunities  Less than a year ago
# 4       I am not interested in new job opportunities  Less than a year ago
#
#                                              LastInt FizzBuzz  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                Interview with people in peer roles       No
# 3  Write code by hand (e.g., on a whiteboard);Int...       No
# 4  Write any code;Write code by hand (e.g., on a ...       No
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
# 2  Languages, frameworks, and other technologies ...
# 3  Languages, frameworks, and other technologies ...
# 4  Industry that I'd be working in;Languages, fra...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
# 2                   I was preparing for a job search            THB
# 3                   I was preparing for a job search            USD
# 4                   I was preparing for a job search            UAH
#
#            CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                   NaN        NaN      NaN            NaN          NaN
# 1                   NaN        NaN      NaN            NaN          NaN
# 2             Thai baht    23000.0  Monthly         8820.0         40.0
# 3  United States dollar    61000.0   Yearly        61000.0         80.0
# 4     Ukrainian hryvnia        NaN      NaN            NaN         55.0
#
#                                             WorkPlan  \
# 0                                                NaN
# 1                                                NaN
# 2  There's no schedule or spec; I work on what se...
# 3  There's no schedule or spec; I work on what se...
# 4  There is a schedule and/or spec (made by me or...
#
#                                        WorkChallenge  \
# 0                                                NaN
# 1                                                NaN
# 2  Distracting work environment;Inadequate access...
# 3                                                NaN
# 4  Being tasked with non-development work;Inadequ...
#
#                          WorkRemote WorkLoc                  ImpSyn  \
# 0                               NaN     NaN                     NaN
# 1                               NaN     NaN                     NaN
# 2  Less than once per month / Never    Home                 Average
# 3  Less than once per month / Never    Home  A little below average
# 4             A few days each month  Office  A little above average
#
#                                    CodeRev  CodeRevHrs  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                       No         NaN
# 3                                       No         NaN
# 4  Yes, because I see value in code review         NaN
#
#                        UnitTests  \
# 0                            NaN
# 1                            NaN
# 2      No, but I think we should
# 3      No, but I think we should
# 4  Yes, it's part of our process
#
#                                          PurchaseHow  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Not sure
# 3  Developers typically have the most influence o...
# 4                                           Not sure
#
#                     PurchaseWhat                           LanguageWorkedWith  \
# 0                            NaN              HTML/CSS;Java;JavaScript;Python
# 1                            NaN                          C++;HTML/CSS;Python
# 2  I have little or no influence                                     HTML/CSS
# 3  I have little or no influence                          C;C++;C#;Python;SQL
# 4  I have little or no influence  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                             LanguageDesireNextYear  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                      C++;HTML/CSS;JavaScript;SQL
# 2                                  Elixir;HTML/CSS
# 3                              C;C#;JavaScript;SQL
# 4         HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                  DatabaseWorkedWith  \
# 0                                            SQLite
# 1                                               NaN
# 2                                        PostgreSQL
# 3                                      MySQL;SQLite
# 4  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                               DatabaseDesireNextYear  \
# 0                                              MySQL
# 1                                              MySQL
# 2                                         PostgreSQL
# 3                                       MySQL;SQLite
# 4  Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                   PlatformWorkedWith                 PlatformDesireNextYear  \
# 0                      MacOS;Windows                Android;Arduino;Windows
# 1                            Windows                                Windows
# 2                                NaN                                    NaN
# 3                      Linux;Windows                          Linux;Windows
# 4  Android;Linux;MacOS;Slack;Windows  Android;Docker;Kubernetes;Linux;Slack
#
#                             WebFrameWorkedWith        WebFrameDesireNextYear  \
# 0                                 Django;Flask                  Flask;jQuery
# 1                                       Django                        Django
# 2                                          NaN                     Other(s):
# 3                                          NaN                           NaN
# 4  Django;Express;Flask;jQuery;React.js;Spring  Flask;jQuery;React.js;Spring
#
#   MiscTechWorkedWith                    MiscTechDesireNextYear  \
# 0            Node.js                                   Node.js
# 1                NaN                                       NaN
# 2                NaN                                       NaN
# 3               .NET                                      .NET
# 4    Cordova;Node.js  Apache Spark;Hadoop;Node.js;React Native
#
#                                      DevEnviron        OpSys  \
# 0                    IntelliJ;Notepad++;PyCharm      Windows
# 1                                  Atom;PyCharm      Windows
# 2                        Vim;Visual Studio Code  Linux-based
# 3  Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                        IntelliJ;Notepad++;Vim  Linux-based
#
#                                Containers BlockchainOrg  \
# 0                 I do not use containers           NaN
# 1                 I do not use containers           NaN
# 2                 I do not use containers           NaN
# 3                 I do not use containers    Not at all
# 4  Outside of work, for personal projects    Not at all
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
# 2                                                NaN        Yes
# 3  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                NaN        Yes
#
#                                    ITperson OffOn SocialMedia  \
# 0  Fortunately, someone else has that title   Yes     Twitter
# 1                                       Yes   Yes   Instagram
# 2                                       Yes   Yes      Reddit
# 3                                      SIGH   Yes      Reddit
# 4                                  Also Yes   Yes    Facebook
#
#                Extraversion ScreenName        SOVisit1st  \
# 0                    Online   Username              2017
# 1                    Online   Username              2017
# 2  In real life (in person)   Username              2011
# 3  In real life (in person)   Username              2014
# 4  In real life (in person)   Username  I don't remember
#
#                        SOVisitFreq  \
# 0  A few times per month or weekly
# 1            Daily or almost daily
# 2             A few times per week
# 3            Daily or almost daily
# 4           Multiple times per day
#
#                                            SOVisitTo  \
# 0  Find answers to specific questions;Learn how t...
# 1  Find answers to specific questions;Learn how t...
# 2  Find answers to specific questions;Learn how t...
# 3  Find answers to specific questions;Pass the ti...
# 4                 Find answers to specific questions
#
#                   SOFindAnswer                     SOTimeSaved  SOHowMuchTime  \
# 0           3-5 times per week  Stack Overflow was much faster  31-60 minutes
# 1           3-5 times per week  Stack Overflow was much faster  11-30 minutes
# 2          6-10 times per week        They were about the same            NaN
# 3           1-2 times per week  Stack Overflow was much faster  31-60 minutes
# 4  More than 10 times per week  Stack Overflow was much faster            NaN
#
#   SOAccount                           SOPartFreq  \
# 0        No                                  NaN
# 1       Yes      A few times per month or weekly
# 2       Yes  Less than once per month or monthly
# 3       Yes  Less than once per month or monthly
# 4       Yes      A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
# 2                                                Yes
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a job board...
#
#                                             EntTeams           SOComm  \
# 0                No, and I don't know what those are          Neutral
# 1                No, and I don't know what those are    Yes, somewhat
# 2  No, I've heard of them, but I am not part of a...          Neutral
# 3                No, and I don't know what those are   No, not really
# 4  No, I've heard of them, but I am not part of a...  Yes, definitely
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# find average age of developer when they worte first line of code

# %%
data1['Age1stCode'].isnull().sum()
# Out:
# 1249

# %%
data1.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
pd.set_option('display.max.columns',None)

# %%
data1['Age1stCode'].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 'Younger than 5 years', '33', '25', '26', '39', '36',
#        '38', '28', '31', 'Older than 85', '32', '37', '50', '65', '42',
#        '34', '40', '67', '43', '44', '60', '46', '45', '49', '51', '41',
#        '55', '83', '48', '53', '54', '47', '56', '79', '61', '68', '77',
#        '66', '52', '80', '62', '84', '57', '58', '63'], dtype=object)

# %%
#masking "older than 85 as 86"

mask = data1['Age1stCode']=='Older than 85'
data1.loc[mask,('Age1stCode')]=86

# %%
#masking "Younger than 5 years" as 4

mask =data1['Age1stCode']=='Younger than 5 years'
data1.loc[mask,('Age1stCode')]=4

# %%
data1['Age1stCode'].isna().sum()
# Out:
# 1249

# %%
data1['Age1stCode']= data1['Age1stCode'].astype('float')

# %%
plt.figure(figsize=(16,5))
sns.countplot(x='Age1stCode',data=data1,order=data1['Age1stCode'].value_counts().iloc[:20].index)
# Out:
# <AxesSubplot:xlabel='Age1stCode', ylabel='count'>

# %%
data1['Age1stCode'].mean()
# Out:
# 15.409395896569825

# %% [markdown]
# The Average age of the developers when theuy wrote first line of code is 15
# followed by 16,14,18

# %% [markdown]
# # Q2 .Deduce the percentage of developers who know python in each country

# %%
data1['Country'].nunique()
# Out:
# 179

# %%
language = data1[data1['LanguageWorkedWith'].notnull()]
language
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88875       88182                                                NaN      Yes
# 88876       88212                                                NaN       No
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88875  OSS is, on average, of HIGHER quality than pro...
# 88876  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment                 Country  \
# 0      Not employed, and not looking for work          United Kingdom
# 1          Not employed, but looking for work  Bosnia and Herzegovina
# 2                          Employed full-time                Thailand
# 3                          Employed full-time           United States
# 4                          Employed full-time                 Ukraine
# ...                                       ...                     ...
# 88875                      Employed part-time                Pakistan
# 88876                      Employed full-time                   Spain
# 88877      Not employed, but looking for work           United States
# 88878  Not employed, and not looking for work                  Canada
# 88882  Not employed, and not looking for work                   Spain
#
#               Student                                            EdLevel  \
# 0                  No                          Primary/elementary school
# 1      Yes, full-time  Secondary school (e.g. American high school, G...
# 2                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...                                                ...
# 88875             NaN  Secondary school (e.g. American high school, G...
# 88876              No  Secondary school (e.g. American high school, G...
# 88877              No  Some college/university study without earning ...
# 88878              No                          Primary/elementary school
# 88882  Yes, full-time                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88875                                                NaN
# 88876                                                NaN
# 88877  Computer science, computer engineering, or sof...
# 88878                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88875  Taken an online course in programming or softw...
# 88876  Taught yourself a new language, framework, or ...
# 88877  Taught yourself a new language, framework, or ...
# 88878  Taught yourself a new language, framework, or ...
# 88882  Taken an online course in programming or softw...
#
#                         OrgSize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88875        10 to 19 employees
# 88876        10 to 19 employees
# 88877                       NaN
# 88878                       NaN
# 88882                       NaN
#
#                                                  DevType YearsCode  \
# 0                                                    NaN         4
# 1      Developer, desktop or enterprise applications;...       NaN
# 2      Designer;Developer, back-end;Developer, front-...         3
# 3                                  Developer, full-stack         3
# 4      Academic researcher;Developer, desktop or ente...        16
# ...                                                  ...       ...
# 88875                                Academic researcher         1
# 88876  Designer;Developer, front-end;Developer, full-...        18
# 88877  Developer, back-end;Developer, desktop or ente...        38
# 88878                                                NaN       NaN
# 88882                                                NaN         8
#
#        Age1stCode      YearsCodePro           CareerSat  \
# 0            10.0               NaN                 NaN
# 1            17.0               NaN                 NaN
# 2            22.0                 1  Slightly satisfied
# 3            16.0  Less than 1 year      Very satisfied
# 4            14.0                 9   Very dissatisfied
# ...           ...               ...                 ...
# 88875         4.0  Less than 1 year                 NaN
# 88876         7.0                15                 NaN
# 88877        10.0                38                 NaN
# 88878         NaN               NaN                 NaN
# 88882        11.0                 3                 NaN
#
#                       JobSat              MgrIdiot  MgrMoney  \
# 0                        NaN                   NaN       NaN
# 1                        NaN                   NaN       NaN
# 2         Slightly satisfied  Not at all confident  Not sure
# 3         Slightly satisfied        Very confident        No
# 4      Slightly dissatisfied    Somewhat confident       Yes
# ...                      ...                   ...       ...
# 88875                    NaN        Very confident  Not sure
# 88876                    NaN    Somewhat confident       Yes
# 88877                    NaN                   NaN       NaN
# 88878                    NaN                   NaN       NaN
# 88882                    NaN                   NaN       NaN
#
#                       MgrWant  \
# 0                         NaN
# 1                         NaN
# 2                    Not sure
# 3                    Not sure
# 4                          No
# ...                       ...
# 88875                     Yes
# 88876  I am already a manager
# 88877                     NaN
# 88878                     NaN
# 88882                     NaN
#
#                                                  JobSeek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88875                                                NaN
# 88876                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                LastHireDate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88875                   NaN
# 88876                   NaN
# 88877                   NaN
# 88878                   NaN
# 88882                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88875                                                NaN      NaN
# 88876                                                NaN      NaN
# 88877                                                NaN      NaN
# 88878                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88875                                                NaN
# 88876                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88875                                                NaN            NaN
# 88876                                                NaN            NaN
# 88877                                                NaN            NaN
# 88878                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88875                   NaN        NaN      NaN            NaN          NaN
# 88876                   NaN        NaN      NaN            NaN          NaN
# 88877                   NaN        NaN      NaN            NaN          NaN
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88875                                                NaN
# 88876                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88875                                                NaN
# 88876                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88875                               NaN     NaN                     NaN
# 88876                               NaN     NaN                     NaN
# 88877                               NaN     NaN                     NaN
# 88878                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88875                                      NaN         NaN
# 88876                                      NaN         NaN
# 88877                                      NaN         NaN
# 88878                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            UnitTests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88875                            NaN
# 88876                            NaN
# 88877                            NaN
# 88878                            NaN
# 88882                            NaN
#
#                                              PurchaseHow  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88875                                                NaN
# 88876                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                         PurchaseWhat  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88875                            NaN
# 88876                            NaN
# 88877                            NaN
# 88878                            NaN
# 88882                            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88875                           HTML/CSS;Java;JavaScript
# 88876                         HTML/CSS;JavaScript;Python
# 88877  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88875                                                NaN
# 88876                                         JavaScript
# 88877  Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      DatabaseWorkedWith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88875                                               NaN
# 88876                                  MySQL;PostgreSQL
# 88877                                               NaN
# 88878                                   Firebase;SQLite
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   DatabaseDesireNextYear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88875                                                NaN
# 88876                                         PostgreSQL
# 88877                                                NaN
# 88878                              Firebase;MySQL;SQLite
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       PlatformWorkedWith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88875              Google Cloud Platform
# 88876                                NaN
# 88877                              Linux
# 88878                              Linux
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88875                                                NaN
# 88876                                            Arduino
# 88877                                 Linux;Raspberry Pi
# 88878                        Google Cloud Platform;Linux
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 WebFrameWorkedWith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88875                                    Other(s):
# 88876                              Django;React.js
# 88877                                     React.js
# 88878                                       jQuery
# 88882                       Django;jQuery;React.js
#
#              WebFrameDesireNextYear      MiscTechWorkedWith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88875                           NaN               Other(s):
# 88876               Django;React.js                     NaN
# 88877                        Vue.js                 Node.js
# 88878                 jQuery;Vue.js                 Node.js
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          MiscTechDesireNextYear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88875                                       NaN
# 88876                                       NaN
# 88877                                   Ansible
# 88878       React Native;Unity 3D;Unreal Engine
# 88882                                       NaN
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88875                                     Android Studio      Windows
# 88876                            Atom;Visual Studio Code        MacOS
# 88877                                                Vim  Linux-based
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers  \
# 0                     I do not use containers
# 1                     I do not use containers
# 2                     I do not use containers
# 3                     I do not use containers
# 4      Outside of work, for personal projects
# ...                                       ...
# 88875                             Development
# 88876                 I do not use containers
# 88877                 I do not use containers
# 88878                 I do not use containers
# 88882                              Production
#
#                                  BlockchainOrg  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                   Not at all
# 4                                   Not at all
# ...                                        ...
# 88875                                      NaN
# 88876  Non-currency applications of blockchain
# 88877                                      NaN
# 88878                                      NaN
# 88882                                      NaN
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88875  Useful across many domains and could change ma...        Yes
# 88876  Useful for immutable record keeping outside of...         No
# 88877                  An irresponsible use of resources         No
# 88878  Useful across many domains and could change ma...        Yes
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITperson  OffOn  \
# 0      Fortunately, someone else has that title    Yes
# 1                                           Yes    Yes
# 2                                           Yes    Yes
# 3                                          SIGH    Yes
# 4                                      Also Yes    Yes
# ...                                         ...    ...
# 88875                                  Also Yes  What?
# 88876                                      SIGH     No
# 88877                                       NaN    Yes
# 88878                                       Yes  What?
# 88882                                  Also Yes    Yes
#
#                     SocialMedia              Extraversion ScreenName  \
# 0                       Twitter                    Online   Username
# 1                     Instagram                    Online   Username
# 2                        Reddit  In real life (in person)   Username
# 3                        Reddit  In real life (in person)   Username
# 4                      Facebook  In real life (in person)   Username
# ...                         ...                       ...        ...
# 88875                   Twitter                   Neither   Username
# 88876                  WhatsApp  In real life (in person)   Username
# 88877  I don't use social media  In real life (in person)   Username
# 88878                   YouTube                       NaN   Username
# 88882                  WhatsApp  In real life (in person)        NaN
#
#              SOVisit1st                                        SOVisitFreq  \
# 0                  2017                    A few times per month or weekly
# 1                  2017                              Daily or almost daily
# 2                  2011                               A few times per week
# 3                  2014                              Daily or almost daily
# 4      I don't remember                             Multiple times per day
# ...                 ...                                                ...
# 88875               NaN  I have never visited Stack Overflow (before to...
# 88876              2008                               A few times per week
# 88877  I don't remember                    A few times per month or weekly
# 88878  I don't remember                               A few times per week
# 88882              2012                              Daily or almost daily
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88875  Get a sense of belonging to the developer comm...
# 88876                 Find answers to specific questions
# 88877                 Find answers to specific questions
# 88878  Find answers to specific questions;Learn how t...
# 88882  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                             SOTimeSaved  \
# 0               3-5 times per week          Stack Overflow was much faster
# 1               3-5 times per week          Stack Overflow was much faster
# 2              6-10 times per week                They were about the same
# 3               1-2 times per week          Stack Overflow was much faster
# 4      More than 10 times per week          Stack Overflow was much faster
# ...                            ...                                     ...
# 88875      Less than once per week  The other resource was slightly faster
# 88876          6-10 times per week      Stack Overflow was slightly faster
# 88877           1-2 times per week                They were about the same
# 88878           3-5 times per week      Stack Overflow was slightly faster
# 88882          6-10 times per week          Stack Overflow was much faster
#
#        SOHowMuchTime SOAccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88875    60+ minutes       NaN
# 88876   0-10 minutes       Yes
# 88877            NaN       Yes
# 88878  11-30 minutes       Yes
# 88882  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88875                                                NaN
# 88876  I have never participated in Q&A on Stack Over...
# 88877  I have never participated in Q&A on Stack Over...
# 88878  I have never participated in Q&A on Stack Over...
# 88882                    A few times per month or weekly
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88875  No, I didn't know that Stack Overflow had a jo...
# 88876  No, I didn't know that Stack Overflow had a jo...
# 88877                                                Yes
# 88878  No, I knew that Stack Overflow had a job board...
# 88882                                                Yes
#
#                                                 EntTeams           SOComm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88875                No, and I don't know what those are          Neutral
# 88876                No, and I don't know what those are   No, not at all
# 88877                No, and I don't know what those are   No, not really
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                            WelcomeChange  \
# 0                Just as welcome now as I felt last year
# 1                Just as welcome now as I felt last year
# 2                Just as welcome now as I felt last year
# 3                Just as welcome now as I felt last year
# 4                Just as welcome now as I felt last year
# ...                                                  ...
# 88875  Not applicable - I did not use Stack Overflow ...
# 88876                                                NaN
# 88877            Just as welcome now as I felt last year
# 88878                                                NaN
# 88882           Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88875       Courses on technologies you're interested in   NaN    Man    No
# 88876  Tech articles written by other developers;Indu...  40.0    Man    No
# 88877                                                NaN   NaN    Man    No
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88875  Straight / Heterosexual
# 88876  Straight / Heterosexual
# 88877  Straight / Heterosexual
# 88878                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88875                                                NaN        Yes
# 88876                       White or of European descent         No
# 88877                                                NaN         No
# 88878                                                NaN         No
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase  Younger than 5 years
# 0      Appropriate in length  Neither easy nor difficult                   NaN
# 1      Appropriate in length  Neither easy nor difficult                   NaN
# 2      Appropriate in length  Neither easy nor difficult                   NaN
# 3      Appropriate in length                        Easy                   NaN
# 4      Appropriate in length                        Easy                   NaN
# ...                      ...                         ...                   ...
# 88875              Too short  Neither easy nor difficult                   4.0
# 88876  Appropriate in length                        Easy                   NaN
# 88877              Too short  Neither easy nor difficult                   NaN
# 88878  Appropriate in length                        Easy                   NaN
# 88882  Appropriate in length                        Easy                   NaN
#
# [87569 rows x 86 columns]

# %%
countries = language['Country'].unique()
countries
# Out:
# array(['United Kingdom', 'Bosnia and Herzegovina', 'Thailand',
#        'United States', 'Ukraine', 'Canada', 'India', 'New Zealand',
#        'Antigua and Barbuda', 'Germany', 'Australia',
#        'Russian Federation', 'Brazil', 'Lithuania', 'Israel',
#        'South Africa', 'Colombia', 'Turkey', 'Argentina', 'Sri Lanka',
#        'Czech Republic', 'Denmark', 'Malaysia', 'Bangladesh', 'Spain',
#        'Serbia', 'Poland', 'Sweden', 'China', 'France', 'Netherlands',
#        'Italy', 'Switzerland', 'Philippines', 'Ireland', 'Pakistan',
#        'Azerbaijan', 'Austria', 'Estonia', 'Croatia', 'South Korea',
#        'Greece', 'Japan', 'Romania', 'Finland', 'Bulgaria', 'Viet Nam',
#        'Slovenia', 'Iran', 'Belarus', 'Hungary', 'Latvia',
#        'Hong Kong (S.A.R.)', 'United Arab Emirates', 'Portugal',
#        'Nigeria', 'Norway', 'Nicaragua', 'Zimbabwe', 'Egypt',
#        'Dominican Republic', 'Guatemala', 'Chile', 'Mexico', 'Ecuador',
#        'Ghana', 'Uganda', 'Cambodia', 'Mauritius', 'Nepal', 'Singapore',
#        'Sierra Leone', 'Republic of Moldova', 'Belgium', 'Armenia',
#        'Bahrain', 'Mongolia', 'Georgia', 'Cyprus', 'Kenya', 'Luxembourg',
#        'Cape Verde', 'Peru', 'Burundi', 'Iraq', 'Slovakia', 'Algeria',
#        'Taiwan', 'Yemen', 'Indonesia', 'Morocco',
#        'Libyan Arab Jamahiriya', 'Belize', 'Mali', 'Trinidad and Tobago',
#        'Venezuela, Bolivarian Republic of...', 'Saudi Arabia', 'Panama',
#        'Lebanon', 'Tunisia', 'Kuwait', 'Andorra', "Côte d'Ivoire",
#        'Syrian Arab Republic', 'El Salvador', 'Cameroon', 'Malta',
#        'Turkmenistan', 'Brunei Darussalam',
#        'Other Country (Not Listed Above)', 'Costa Rica', 'Jordan',
#        'Albania', 'Uzbekistan', 'Sudan', 'Kazakhstan',
#        'The former Yugoslav Republic of Macedonia', 'Ethiopia',
#        'Paraguay', 'Myanmar', 'Somalia', 'Guyana', 'Honduras', 'Qatar',
#        'Jamaica', 'Fiji', 'Haiti', 'Democratic Republic of the Congo',
#        'Benin', 'Namibia', 'Montenegro', 'Rwanda', 'Uruguay',
#        'Mauritania', 'Bolivia', 'Gabon', 'Liechtenstein',
#        'United Republic of Tanzania', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Madagascar', 'Guinea',
#        'Afghanistan', 'Republic of Korea', 'Cuba', 'Maldives', 'Monaco',
#        'Tajikistan', 'North Korea', 'Senegal', 'Angola', 'Iceland',
#        'Togo', 'Swaziland', 'Congo, Republic of the...', 'Zambia', 'Oman',
#        'Timor-Leste', 'Tonga', 'Niger', 'Mozambique', 'Botswana',
#        'Dominica', 'Papua New Guinea', 'Barbados', 'Seychelles',
#        'Lesotho', "Democratic People's Republic of Korea", 'Bahamas',
#        'Burkina Faso', 'Saint Kitts and Nevis', 'Malawi', 'Bhutan',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Djibouti', 'Chad'], dtype=object)

# %%
country_py ={}

# %%
#total countries where is programming language for developers

for country in countries:
    for i in language.groupby(['Country'])['LanguageWorkedWith'].value_counts()[country].index:  #groupby Country and 
        l =[]
        l.append(i.split(';'))
        # print(l)
        for j in l:
            if 'Python' in j:
                if country not in country_py.keys():
                    country_py[country] =1
                else:
                    country_py[country] +=1

# %%
country_py
# Out:
# {'United Kingdom': 1336,
#  'Bosnia and Herzegovina': 29,
#  'Thailand': 84,
#  'United States': 4504,
#  'Ukraine': 192,
#  'Canada': 1044,
#  'India': 1391,
#  'New Zealand': 216,
#  'Germany': 1494,
#  'Australia': 592,
#  'Russian Federation': 504,
#  'Brazil': 549,
#  'Lithuania': 72,
#  'Israel': 327,
#  'South Africa': 167,
#  'Colombia': 85,
#  'Turkey': 296,
#  'Argentina': 153,
#  'Sri Lanka': 121,
#  'Czech Republic': 228,
#  'Denmark': 204,
#  'Malaysia': 94,
#  'Bangladesh': 161,
#  'Spain': 468,
#  'Serbia': 105,
#  'Poland': 504,
#  'Sweden': 384,
#  'China': 217,
#  'France': 748,
#  'Netherlands': 559,
#  'Italy': 484,
#  'Switzerland': 373,
#  'Philippines': 106,
#  'Ireland': 183,
#  'Pakistan': 209,
#  'Azerbaijan': 16,
#  'Austria': 290,
#  'Estonia': 75,
#  'Croatia': 80,
#  'South Korea': 73,
#  'Greece': 184,
#  'Japan': 162,
#  'Romania': 193,
#  'Finland': 224,
#  'Bulgaria': 152,
#  'Viet Nam': 74,
#  'Slovenia': 112,
#  'Iran': 211,
#  'Belarus': 62,
#  'Hungary': 165,
#  'Latvia': 37,
#  'Hong Kong (S.A.R.)': 82,
#  'United Arab Emirates': 47,
#  'Portugal': 153,
#  'Nigeria': 109,
#  'Norway': 196,
#  'Nicaragua': 10,
#  'Zimbabwe': 14,
#  'Egypt': 101,
#  'Dominican Republic': 21,
#  'Guatemala': 25,
#  'Chile': 93,
#  'Mexico': 213,
#  'Ecuador': 39,
#  'Ghana': 32,
#  'Uganda': 44,
#  'Cambodia': 9,
#  'Mauritius': 8,
#  'Nepal': 88,
#  'Singapore': 125,
#  'Sierra Leone': 1,
#  'Republic of Moldova': 7,
#  'Belgium': 248,
#  'Armenia': 28,
#  'Bahrain': 4,
#  'Mongolia': 8,
#  'Georgia': 23,
#  'Cyprus': 20,
#  'Kenya': 100,
#  'Luxembourg': 23,
#  'Peru': 46,
#  'Burundi': 1,
#  'Iraq': 17,
#  'Slovakia': 82,
#  'Algeria': 37,
#  'Taiwan': 82,
#  'Yemen': 3,
#  'Indonesia': 130,
#  'Morocco': 48,
#  'Libyan Arab Jamahiriya': 2,
#  'Belize': 1,
#  'Mali': 1,
#  'Trinidad and Tobago': 5,
#  'Venezuela, Bolivarian Republic of...': 27,
#  'Saudi Arabia': 33,
#  'Panama': 13,
#  'Lebanon': 41,
#  'Tunisia': 36,
#  'Kuwait': 6,
#  "Côte d'Ivoire": 11,
#  'Syrian Arab Republic': 7,
#  'El Salvador': 19,
#  'Cameroon': 16,
#  'Malta': 19,
#  'Turkmenistan': 6,
#  'Other Country (Not Listed Above)': 35,
#  'Costa Rica': 30,
#  'Jordan': 21,
#  'Albania': 23,
#  'Uzbekistan': 14,
#  'Sudan': 16,
#  'Kazakhstan': 14,
#  'The former Yugoslav Republic of Macedonia': 8,
#  'Ethiopia': 20,
#  'Paraguay': 18,
#  'Myanmar': 8,
#  'Somalia': 3,
#  'Guyana': 2,
#  'Honduras': 12,
#  'Qatar': 5,
#  'Jamaica': 8,
#  'Fiji': 1,
#  'Haiti': 3,
#  'Democratic Republic of the Congo': 3,
#  'Benin': 3,
#  'Namibia': 3,
#  'Montenegro': 8,
#  'Rwanda': 5,
#  'Uruguay': 36,
#  'Mauritania': 5,
#  'Bolivia': 10,
#  'Liechtenstein': 1,
#  'United Republic of Tanzania': 15,
#  'Kyrgyzstan': 6,
#  'Madagascar': 4,
#  'Guinea': 2,
#  'Afghanistan': 6,
#  'Republic of Korea': 20,
#  'Cuba': 16,
#  'Maldives': 6,
#  'Monaco': 2,
#  'Senegal': 8,
#  'Angola': 2,
#  'Iceland': 29,
#  'Togo': 1,
#  'Swaziland': 2,
#  'Congo, Republic of the...': 4,
#  'Zambia': 4,
#  'Oman': 6,
#  'Timor-Leste': 1,
#  'Niger': 1,
#  'Mozambique': 1,
#  'Botswana': 1,
#  'Dominica': 1,
#  'Barbados': 1,
#  'Seychelles': 1,
#  'Lesotho': 1,
#  "Democratic People's Republic of Korea": 1,
#  'Bahamas': 2,
#  'Bhutan': 1,
#  'San Marino': 1,
#  'Sao Tome and Principe': 1}

# %%
def plot_dim_count(unique_dim_dict,plot_title):  #returns two values
    dim_count =pd.DataFrame.from_dict(unique_dim_dict,orient='index',dtype=None)
    dim_count.columns =['Count']
    dim_count.sort_values('Count',ascending=False,inplace=True)
    
    dim_count[:10].plot(kind='pie', figsize =(12,12),fontsize =10,title =plot_title,subplots=True,autopct= '%1.1f%%');
    print(dim_count[:10])

# %%
plot_dim_count(country_py,'Most Popular Languages')
# Out:
#                     Count
# United States        4504
# Germany              1494
# India                1391
# United Kingdom       1336
# Canada               1044
# France                748
# Australia             592
# Netherlands           559
# Brazil                549
# Russian Federation    504

# %% [markdown]
# # The Country where maximum number of python developer are united states Followed by Germany, INdia and United Kingdom

# %% [markdown]
# # Q3 - Generate a report for the average salary of developed based on continent

# %%
# !pip install pycountry_convert
# Out:
# Collecting pycountry_convert
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saura\anaconda3\lib\site-packages)
#   Using cached pycountry_convert-0.7.2-py3-none-any.whl (13 kB)
# Collecting pprintpp>=0.3.0
#   Using cached pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Collecting pytest-cov>=2.5.1
#   Downloading pytest_cov-4.0.0-py3-none-any.whl (21 kB)
# Collecting repoze.lru>=0.7
#   Using cached repoze.lru-0.7-py3-none-any.whl (10 kB)
# Collecting pycountry>=16.11.27.1
#   Using cached pycountry-22.3.5.tar.gz (10.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pytest-mock>=1.6.3
#   Using cached pytest_mock-3.10.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: wheel>=0.30.0 in c:\users\saura\anaconda3\lib\site-packages (from pycountry_convert) (0.37.1)
# Requirement already satisfied: pytest>=3.4.0 in c:\users\saura\anaconda3\lib\site-packages (from pycountry_convert) (7.1.1)
# Requirement already satisfied: setuptools in c:\users\saura\anaconda3\lib\site-packages (from pycountry>=16.11.27.1->pycountry_convert) (61.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.1.1)
# Requirement already satisfied: packaging in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.2.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.4.0)
# Requirement already satisfied: colorama in c:\users\saura\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.4.6)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.2.5-cp39-cp39-win_amd64.whl (203 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\saura\anaconda3\lib\site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (3.0.4)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517): started
#   Building wheel for pycountry (PEP 517): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681896 sha256=c374e900a0a9884a1da6dd707f1e65b8b6c627f1fc31bc67cd204fddd85809db
#   Stored in directory: c:\users\saura\appdata\local\pip\cache\wheels\47\15\92\e6dc85fcb0686c82e1edbcfdf80cfe4808c058813fed0baa8f
# Successfully built pycountry
# Installing collected packages: coverage, repoze.lru, pytest-mock, pytest-cov, pycountry, pprintpp, pycountry-convert
# Successfully installed coverage-7.2.5 pprintpp-0.4.0 pycountry-22.3.5 pycountry-convert-0.7.2 pytest-cov-4.0.0 pytest-mock-3.10.0 repoze.lru-0.7

# %%
import pycountry_convert as pc

# %%
#getting the continent of each country present  in a dataset

def country_to_continent(country_name):
    if country_name != 'Other Country(Not Listed Above)':
#        print(Country_name)
        try:
            country_alpha2 =pc.country_name_to_country_alpha2(country_name)
    #           print(country_alpha2)
            country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
          #print(country_continent_code)
            country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
            return country_continent_name
        except :
            return "unknown"
        else:
            return "unknown"

# %%
data1.Country.unique()
# Out:
# array(['United Kingdom', 'Bosnia and Herzegovina', 'Thailand',
#        'United States', 'Ukraine', 'Canada', 'India', 'New Zealand',
#        'Antigua and Barbuda', 'Germany', 'Australia',
#        'Russian Federation', 'Brazil', 'Lithuania', 'Israel',
#        'South Africa', 'Colombia', 'Turkey', 'Switzerland', 'Argentina',
#        'Sri Lanka', 'Czech Republic', 'Denmark', 'Malaysia', 'Bangladesh',
#        'Spain', 'Serbia', 'Poland', 'Sweden', 'China', 'France',
#        'Netherlands', 'Italy', 'Philippines', 'Ireland', 'Pakistan',
#        'Azerbaijan', 'Austria', 'Estonia', 'Croatia', 'South Korea',
#        'Greece', 'Japan', 'Romania', 'Finland', 'Bulgaria', 'Viet Nam',
#        'Slovenia', 'Iran', 'Belarus', 'Hungary', 'Latvia',
#        'Hong Kong (S.A.R.)', 'United Arab Emirates', 'Portugal',
#        'Nigeria', 'Norway', 'Nicaragua', 'Zimbabwe', 'Egypt', 'Mexico',
#        'Dominican Republic', 'Guatemala', 'Chile', 'Ecuador', 'Ghana',
#        'Uganda', 'Cambodia', 'Mauritius', 'Nepal', 'Singapore',
#        'Sierra Leone', 'Republic of Moldova', 'Belgium', 'Armenia',
#        'Afghanistan', 'Bahrain', 'Mongolia', 'Georgia', 'Cyprus', 'Kenya',
#        'Luxembourg', 'Saudi Arabia', 'Cape Verde', 'Peru', 'Burundi',
#        'Iraq', 'Slovakia', 'Algeria', 'Taiwan', 'Yemen', 'Indonesia',
#        'Morocco', 'Libyan Arab Jamahiriya', 'Belize', 'Mali',
#        'Trinidad and Tobago', 'Venezuela, Bolivarian Republic of...',
#        'Panama', 'Lebanon', 'Tunisia', 'Kuwait', 'Andorra',
#        "Côte d'Ivoire", 'Syrian Arab Republic', 'El Salvador', 'Cameroon',
#        'Malta', 'Turkmenistan', 'Brunei Darussalam',
#        'Other Country (Not Listed Above)', 'Costa Rica', 'Jordan',
#        'Albania', 'Uzbekistan', 'Sudan', 'Kazakhstan',
#        'The former Yugoslav Republic of Macedonia', 'Ethiopia',
#        'Paraguay', 'Myanmar', 'Somalia', 'Guyana', 'Honduras', 'Qatar',
#        'Jamaica', 'Fiji', 'Haiti', 'Democratic Republic of the Congo',
#        'Benin', 'Namibia', 'Montenegro', 'Rwanda', 'Tajikistan',
#        'Uruguay', 'Mauritania', 'Bolivia', 'Gabon', 'Liechtenstein',
#        'United Republic of Tanzania', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Madagascar', 'Guinea',
#        'Republic of Korea', 'Cuba', 'Maldives', 'Monaco', 'North Korea',
#        'Senegal', 'Angola', 'Iceland', 'Togo', 'Swaziland',
#        'Congo, Republic of the...', 'Zambia', 'Oman', 'Timor-Leste',
#        'Tonga', 'Djibouti', "Democratic People's Republic of Korea",
#        'Niger', 'Mozambique', 'Botswana', 'Dominica', 'Papua New Guinea',
#        'Barbados', 'Seychelles', 'Lesotho', 'Bahamas', 'Burkina Faso',
#        'Saint Kitts and Nevis', 'Malawi', 'Liberia', 'Bhutan',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Chad', nan], dtype=object)

# %%
# correcting the name of each country which is mistypes

data1['Country'].replace({'Hong Kong (S.A.R.)':'Hong Kong'},inplace=True)
data1['Country'].replace({"The former Yugoslav Republic of Macedonia":"North Macedonia"},inplace=True)
data1['Country'].replace({"Congo, Republic of the...":"Republic of the Congo"},inplace=True)
data1['Country'].replace({"Venezuela, Bolivarian Republic of...":'Venezuela'},inplace=True)
data1['Country'].replace({'Timor-Leste':'East Timor'},inplace=True)
data1['Country'].replace({'Libyan Arab Jamahiriya':'Libya'},inplace=True)
data1['Country'].replace({'Republic of Korea':'South Korea'},inplace=True)

# %%
names = [country_to_continent(i) for i in data1['Country']]
data1['Continent']= names

# %%
salary_notnull = data1[data1['ConvertedComp'].notnull()]

# %%
salary_notnull.head(1)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#   OpenSourcer                                         OpenSource  \
# 2       Never  The quality of OSS and closed source software ...
#
#            Employment   Country Student  \
# 2  Employed full-time  Thailand      No
#
#                                     EdLevel                 UndergradMajor  \
# 2  Bachelor’s degree (BA, BS, B.Eng., etc.)  Web development or web design
#
#                                             EduOther               OrgSize  \
# 2  Taught yourself a new language, framework, or ...  100 to 499 employees
#
#                                              DevType YearsCode  Age1stCode  \
# 2  Designer;Developer, back-end;Developer, front-...         3        22.0
#
#   YearsCodePro           CareerSat              JobSat              MgrIdiot  \
# 2            1  Slightly satisfied  Slightly satisfied  Not at all confident
#
#    MgrMoney   MgrWant                                            JobSeek  \
# 2  Not sure  Not sure  I’m not actively looking, but I am open to new...
#
#     LastHireDate                              LastInt FizzBuzz  \
# 2  1-2 years ago  Interview with people in peer roles       No
#
#                                           JobFactors  \
# 2  Languages, frameworks, and other technologies ...
#
#                        ResumeUpdate CurrencySymbol CurrencyDesc  CompTotal  \
# 2  I was preparing for a job search            THB    Thai baht    23000.0
#
#   CompFreq  ConvertedComp  WorkWeekHrs  \
# 2  Monthly         8820.0         40.0
#
#                                             WorkPlan  \
# 2  There's no schedule or spec; I work on what se...
#
#                                        WorkChallenge  \
# 2  Distracting work environment;Inadequate access...
#
#                          WorkRemote WorkLoc   ImpSyn CodeRev  CodeRevHrs  \
# 2  Less than once per month / Never    Home  Average      No         NaN
#
#                    UnitTests PurchaseHow                   PurchaseWhat  \
# 2  No, but I think we should    Not sure  I have little or no influence
#
#   LanguageWorkedWith LanguageDesireNextYear DatabaseWorkedWith  \
# 2           HTML/CSS        Elixir;HTML/CSS         PostgreSQL
#
#   DatabaseDesireNextYear PlatformWorkedWith PlatformDesireNextYear  \
# 2             PostgreSQL                NaN                    NaN
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith  \
# 2                NaN              Other(s):                NaN
#
#   MiscTechDesireNextYear              DevEnviron        OpSys  \
# 2                    NaN  Vim;Visual Studio Code  Linux-based
#
#                 Containers BlockchainOrg BlockchainIs BetterLife ITperson  \
# 2  I do not use containers           NaN          NaN        Yes      Yes
#
#   OffOn SocialMedia              Extraversion ScreenName SOVisit1st  \
# 2   Yes      Reddit  In real life (in person)   Username       2011
#
#             SOVisitFreq                                          SOVisitTo  \
# 2  A few times per week  Find answers to specific questions;Learn how t...
#
#           SOFindAnswer               SOTimeSaved SOHowMuchTime SOAccount  \
# 2  6-10 times per week  They were about the same           NaN       Yes
#
#                             SOPartFreq SOJobs  \
# 2  Less than once per month or monthly    Yes
#
#                                             EntTeams   SOComm  \
# 2  No, I've heard of them, but I am not part of a...  Neutral
#
#                              WelcomeChange  \
# 2  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 2  Straight / Heterosexual       NaN        Yes  Appropriate in length
#
#                    SurveyEase  Younger than 5 years Continent
# 2  Neither easy nor difficult                   NaN      Asia

# %%
a = salary_notnull.groupby(['Continent'])['ConvertedComp'].mean().sort_values(ascending =False)

# %%
salary_notnull.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase',
#        'Younger than 5 years', 'Continent'],
#       dtype='object')

# %%
a.index
# Out:
# Index(['North America', 'Oceania', 'unknown', 'Europe', 'Asia', 'Africa',
#        'South America'],
#       dtype='object', name='Continent')

# %%
plt.figure(figsize=(16,10))
plt.title('Salary countplot based on continent', fontsize =20,fontweight='bold',y=1.05)
plt.ylabel('Salary',fontsize=15)
plt.xlabel('Continent',fontsize=15)
a.plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Salary countplot based on continent'}, xlabel='Continent', ylabel='Salary'>

# %% [markdown]
# # Developer with high salary belong to North America, Oceania and Europe

# %% [markdown]
# # Q4 - Based on this Survey, What will be the most desired programming language for the year 2020

# %%
lang_desired = data1[data1['LanguageDesireNextYear'].notnull()]
lang_desired.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# 0            NaN  Taught yourself a new language, framework, or ...     NaN
# 1            NaN  Taken an online course in programming or softw...     NaN
#
#                                              DevType YearsCode  Age1stCode  \
# 0                                                NaN         4        10.0
# 1  Developer, desktop or enterprise applications;...       NaN        17.0
#
#   YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant  \
# 0          NaN       NaN    NaN      NaN      NaN     NaN
# 1          NaN       NaN    NaN      NaN      NaN     NaN
#
#                            JobSeek          LastHireDate LastInt FizzBuzz  \
# 0                              NaN                   NaN     NaN      NaN
# 1  I am actively looking for a job  I've never had a job     NaN      NaN
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
#
#   CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan  \
# 0          NaN        NaN      NaN            NaN          NaN      NaN
# 1          NaN        NaN      NaN            NaN          NaN      NaN
#
#   WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests  \
# 0           NaN        NaN     NaN    NaN     NaN         NaN       NaN
# 1           NaN        NaN     NaN    NaN     NaN         NaN       NaN
#
#   PurchaseHow PurchaseWhat               LanguageWorkedWith  \
# 0         NaN          NaN  HTML/CSS;Java;JavaScript;Python
# 1         NaN          NaN              C++;HTML/CSS;Python
#
#                             LanguageDesireNextYear DatabaseWorkedWith  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite
# 1                      C++;HTML/CSS;JavaScript;SQL                NaN
#
#   DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith  \
# 0       Django;Flask           Flask;jQuery            Node.js
# 1             Django                 Django                NaN
#
#   MiscTechDesireNextYear                  DevEnviron    OpSys  \
# 0                Node.js  IntelliJ;Notepad++;PyCharm  Windows
# 1                    NaN                Atom;PyCharm  Windows
#
#                 Containers BlockchainOrg  \
# 0  I do not use containers           NaN
# 1  I do not use containers           NaN
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
#
#                                    ITperson OffOn SocialMedia Extraversion  \
# 0  Fortunately, someone else has that title   Yes     Twitter       Online
# 1                                       Yes   Yes   Instagram       Online
#
#   ScreenName SOVisit1st                      SOVisitFreq  \
# 0   Username       2017  A few times per month or weekly
# 1   Username       2017            Daily or almost daily
#
#                                            SOVisitTo        SOFindAnswer  \
# 0  Find answers to specific questions;Learn how t...  3-5 times per week
# 1  Find answers to specific questions;Learn how t...  3-5 times per week
#
#                       SOTimeSaved  SOHowMuchTime SOAccount  \
# 0  Stack Overflow was much faster  31-60 minutes        No
# 1  Stack Overflow was much faster  11-30 minutes       Yes
#
#                         SOPartFreq  \
# 0                              NaN
# 1  A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
#
#                               EntTeams         SOComm  \
# 0  No, and I don't know what those are        Neutral
# 1  No, and I don't know what those are  Yes, somewhat
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
# 1  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase  Younger than 5 years Continent
# 0  Neither easy nor difficult                   NaN    Europe
# 1  Neither easy nor difficult                   NaN    Europe

# %%
unique_lang ={}

# %%
#getting the list of total no. of unique languages

for language_set in language['LanguageDesireNextYear'].apply(lambda row :str(row).split(';')):  #splitted languages from languagedesirednextyear by lambda function
    for language in language_set:    #(from language set  extracted languages and added in the dict)
        if language not in unique_lang.keys():
            unique_lang[language]=1
        else:
            unique_lang[language] +=1

# %%
unique_lang
# Out:
# {'C': 11008,
#  'C++': 16681,
#  'C#': 22300,
#  'Go': 16995,
#  'HTML/CSS': 36389,
#  'Java': 23259,
#  'JavaScript': 44428,
#  'Python': 39720,
#  'SQL': 33349,
#  'Elixir': 3758,
#  'WebAssembly': 8384,
#  'Scala': 5533,
#  'Bash/Shell/PowerShell': 21217,
#  'Erlang': 2095,
#  'Ruby': 7188,
#  'Rust': 10463,
#  'TypeScript': 23640,
#  'Other(s):': 7862,
#  'Kotlin': 13192,
#  'R': 6665,
#  'Assembly': 4496,
#  'Objective-C': 2804,
#  'PHP': 12688,
#  'Swift': 8743,
#  'VBA': 1591,
#  'Clojure': 2717,
#  'Dart': 4391,
#  'nan': 4109,
#  'F#': 3489}

# %%
def plot_dimension_count(unique_dim_dict,plot_title):
    dim_count = pd.DataFrame.from_dict(unique_dim_dict,orient='index',dtype=None)
    dim_count.columns =['Count']
    dim_count.sort_values('Count',ascending=True,inplace=True)
    dim_count.plot(kind ='barh',figsize=(14,13),fontsize =10,title =plot_title)

# %%
plot_dimension_count(unique_lang,'Most Popular Languages')

# %% [raw]
# # According to the survey most desired language for the next year is Javascript followed by Python,HTML/CSS AND SQL

# %% [markdown]
# # Q5 - What is the distribution of people who code as a  hobby based on gender and continent (hint : use your mapping of country to continent)?

# %%
data1['Gender'].unique()
# Out:
# array(['Man', nan, 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man',
#        'Man;Non-binary, genderqueer, or gender non-conforming'],
#       dtype=object)

# %%
df_hobby = data1[data1['Hobbyist']=='Yes']

# %%
data1['Hobbyist']= data1['Hobbyist'].map({'Yes':1,'No':0})

# %%
#Total unique members belonging to category of gender

data1['Gender'].value_counts()
# Out:
# Man                                                            77919
# Woman                                                           6344
# Non-binary, genderqueer, or gender non-conforming                597
# Man;Non-binary, genderqueer, or gender non-conforming            181
# Woman;Non-binary, genderqueer, or gender non-conforming          163
# Woman;Man                                                        132
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       70
# Name: Gender, dtype: int64

# %%
#gender shoula be divided ib=nto only three categories if record has any other value consider it as others
l =[]

for i in data1['Gender']:
    if i !='Man' and i != 'Woman':
        l.append('Others')
    else:
        l.append(i)

# %%
data1['Gender']=l

# %%
data1['Gender'].value_counts()
# Out:
# Man       77919
# Woman      6344
# Others     4620
# Name: Gender, dtype: int64

# %%
#barplot for gender, hobbyist and continent

plt.figure(figsize=(15,10))

sns.barplot(x='Gender',y='Hobbyist',hue='Continent',data=data1)
plt.title('Distribution of People who code based on gender and continent as hobby ')
plt.grid()

N =3
ind = np.arange(N)
s = (data1['Gender'].value_counts().index)
plt.xticks(ind,s,rotation ='vertical',fontsize =15)

plt.show()

# %% [markdown]
# Maximum women who are habitual coders belong to Oceania,Europe and Africa as for men habitual coders belong to Oceania, Europe and Noth America

# %% [markdown]
# # Q6 =Generate the report for job and career satisfaction of developer based on their gender and continent

# %%
data1['JobSat'].value_counts()
# Out:
# Slightly satisfied                    24207
# Very satisfied                        22452
# Slightly dissatisfied                 10752
# Neither satisfied nor dissatisfied     8720
# Very dissatisfied                      4857
# Name: JobSat, dtype: int64

# %%
data1['JobSat'] = data1['JobSat'].map({'Slightly satisfied':1,'Very satisfied':2,'Slightly dissatisfied':3,'Neither satisfied nor dissatisfied':4,'Very dissatisfied':5})

# %%
data1['JobSat'].value_counts()
# Out:
# 1.0    24207
# 2.0    22452
# 3.0    10752
# 4.0     8720
# 5.0     4857
# Name: JobSat, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Gender',y='JobSat',hue='Continent',data=data1)
plt.grid()
plt.title('Distribution of developers job and career satisfaction based on Gender and Continent')


N=3
ind = np.arange(N)
s = (data1['Gender'].value_counts().index)
plt.xticks(ind,s,rotation ='vertical',fontsize = 12)

plt.show()

# %% [markdown]
# Maximum Job Satisaction for developers belonging to Asia whereas developer who are dissatisfied belonging to North America.
